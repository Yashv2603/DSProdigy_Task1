# %%
#Importing Libraries#

# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\91879\Downloads\worldpopulationdata.csv")
data
# Out:
#                                    Series Name        Series Code  \
# 0                            Population, total        SP.POP.TOTL
# 1                            Population, total        SP.POP.TOTL
# 2                            Population, total        SP.POP.TOTL
# 3                            Population, total        SP.POP.TOTL
# 4                            Population, total        SP.POP.TOTL
# ...                                        ...                ...
# 1080  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1081  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1082  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1083  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1084  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
#
#                Country Name Country Code          2022          2021  \
# 0               Afghanistan          AFG  4.112877e+07  4.009946e+07
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1085 entries, 0 to 1084
# Data columns (total 26 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Series Name   1085 non-null   object
#  1   Series Code   1085 non-null   object
#  2   Country Name  1085 non-null   object
#  3   Country Code  1085 non-null   object
#  4   2022          1085 non-null   float64
#  5   2021          1085 non-null   float64
#  6   2020          1085 non-null   float64
#  7   2019          1085 non-null   float64
#  8   2018          1085 non-null   float64
#  9   2017          1085 non-null   float64
#  10  2016          1085 non-null   float64
#  11  2015          1085 non-null   float64
#  12  2014          1085 non-null   float64
#  13  2013          1085 non-null   float64
#  14  2012          1085 non-null   float64
#  15  2011          1085 non-null   float64
#  16  2010          1085 non-null   float64
# ...

# %%
data.describe()
# Out:
#                2022          2021          2020          2019          2018  \
# count  1.085000e+03  1.085000e+03  1.085000e+03  1.085000e+03  1.085000e+03
# mean   1.461378e+07  1.449711e+07  1.437307e+07  1.422876e+07  1.407966e+07
# std    7.832944e+07  7.801505e+07  7.763257e+07  7.712985e+07  7.657562e+07
# min    2.749000e+01  2.732503e+01  2.735104e+01  2.676295e+01  2.573928e+01
# 25%    5.034029e+01  5.035172e+01  5.034171e+01  5.033040e+01  5.033917e+01
# 50%    1.465500e+05  1.463660e+05  1.461650e+05  1.459570e+05  1.457520e+05
# 75%    5.903468e+06  5.856733e+06  5.831404e+06  5.814422e+06  5.774185e+06
# max    1.417173e+09  1.412360e+09  1.411100e+09  1.407745e+09  1.402760e+09
#
#                2017          2016          2015          2014          2013  \
# count  1.085000e+03  1.085000e+03  1.085000e+03  1.085000e+03  1.085000e+03
# mean   1.392568e+07  1.376711e+07  1.360705e+07  1.344625e+07  1.328368e+07
# ...

# %%
data.isna().sum()
# Out:
# Series Name     0
# Series Code     0
# Country Name    0
# Country Code    0
# 2022            0
# 2021            0
# 2020            0
# 2019            0
# 2018            0
# 2017            0
# 2016            0
# 2015            0
# 2014            0
# 2013            0
# 2012            0
# 2011            0
# 2010            0
# 2009            0
# 2008            0
# 2007            0
# 2006            0
# 2005            0
# 2004            0
# 2003            0
# 2002            0
# 2001            0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.drop(['Series Name','Country Code'],axis=1,inplace=True)
data.columns
# Out:
# Index(['Series Code', 'Country Name', '2022', '2021', '2020', '2019', '2018',
#        '2017', '2016', '2015', '2014', '2013', '2012', '2011', '2010', '2009',
#        '2008', '2007', '2006', '2005', '2004', '2003', '2002', '2001'],
#       dtype='object')

# %%
#Histogram of Total Population

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
total_population_data = data[data['Series Code'] == 'SP.POP.TOTL'].copy()
numeric_columns = total_population_data.select_dtypes(include='number').columns
total_population_data['Row Total'] = total_population_data[numeric_columns].sum(axis=1)
plt.hist(total_population_data['Row Total'])
plt.xlabel('total population')
plt.ylabel('Frequency')
plt.title('Distribution of Total Population')
plt.show()

# %%
#Extraction of top-10 countries with respect to total population
# Out:
#   Cell In[39], line 1
#     ***Extraction of top-10 countries with respect to total population***
#     ^
# SyntaxError: invalid syntax

# %%
total_population_sorted = total_population_data.sort_values(by="Row Total", ascending=False)
total_top_ten_countries = total_population_sorted.head(10)
print("Top ten countries with highest row totals of population total column\n")
print(total_top_ten_countries[['Country Name', 'Row Total']])
# Out:
# Top ten countries with highest row totals of population total column
#
#            Country Name     Row Total
# 41                China  2.970730e+10
# 89                India  2.773808e+10
# 206       United States  6.851667e+09
# 90            Indonesia  5.454672e+09
# 26               Brazil  4.364663e+09
# 149            Pakistan  4.357602e+09
# 144             Nigeria  3.726423e+09
# 15           Bangladesh  3.338165e+09
# 161  Russian Federation  3.164137e+09
# 98                Japan  2.799765e+09

# %%
#Bar plot
#Top ten countries of total population
# Create the bar plot
plt.figure(figsize=(15, 6))
plt.subplot(2,2,1)
sns.barplot(x="Row Total", y="Country Name", data=total_top_ten_countries, palette="plasma")
plt.title("Top Ten Countries of Total Population",fontsize=10)
plt.xlabel("Total Population",fontsize=10)
plt.ylabel("Country",fontsize=10)
plt.show()

# %%
#Scatter plot
#Top ten countries of total population
plt.scatter(x="Row Total", y="Country Name", data=total_top_ten_countries,color='red')
plt.title("Scatter Plot",fontsize=10)
plt.xlabel("Total Population",fontsize=10)
plt.ylabel("Country",fontsize=10)
plt.show()

# %%
#Histogram of Total Male Population
male_population_data = data[data["Series Code"] == "SP.POP.TOTL.MA.IN"].copy()
numeric_columns = male_population_data.select_dtypes(include='number').columns
male_population_data['Row Total'] = male_population_data[numeric_columns].sum(axis=1)
plt.hist(male_population_data['Row Total'])
plt.xlabel('total Male population')
plt.ylabel('Frequency')
plt.title('Distribution of Total Male Population')
plt.show()

# %%
#Extraction of top ten countries with respect to male population
male_population_sorted = male_population_data.sort_values(by="Row Total", ascending=False)
male_top_ten_countries = male_population_sorted.head(10)
print("top ten countries male population total \n")
print(male_top_ten_countries[['Country Name', 'Row Total']])
# Out:
# top ten countries male population total
#
#            Country Name     Row Total
# 475               China  1.519523e+10
# 523               India  1.433801e+10
# 640       United States  3.382847e+09
# 524           Indonesia  2.746650e+09
# 583            Pakistan  2.229730e+09
# 460              Brazil  2.151035e+09
# 578             Nigeria  1.878457e+09
# 449          Bangladesh  1.670997e+09
# 595  Russian Federation  1.467737e+09
# 532               Japan  1.364356e+09

# %%
#Bar plot
#Top ten countries of male population
# Create the bar plot
plt.figure(figsize=(15, 6))
plt.subplot(2,2,1)
sns.barplot(x="Row Total", y="Country Name", data=male_top_ten_countries, palette="plasma")
print("top ten countries male population total \n")
plt.title("Top Ten Countries of Male Population",fontsize=10)
plt.xlabel("Total Male Population",fontsize=10)
plt.ylabel("Country",fontsize=10)
plt.show()
# Out:
# top ten countries male population total

# %%
#Scatter plot
#Top ten countries of total male population
plt.scatter(x="Row Total", y="Country Name", data=male_top_ten_countries,color='red')
plt.title("Scatter Plot",fontsize=10)
plt.xlabel("Total Male Population",fontsize=10)
plt.ylabel("Country",fontsize=10)
plt.show()

# %%
#Histogram of Total Female Population
# Filter data for female population
female_population_data = data[data["Series Code"] == "SP.POP.TOTL.FE.IN"].copy()
numeric_columns = female_population_data.select_dtypes(include='number').columns
female_population_data['Row Total'] = female_population_data[numeric_columns].sum(axis=1)
plt.hist(female_population_data['Row Total'])
plt.xlabel('Total Female population')
plt.ylabel('Frequency')
plt.title('Distribution of Total Female Population')
plt.show()

# %%
#Extraction of top ten countries with respect to female population
female_population_sorted = female_population_data.sort_values(by="Row Total", ascending=False)
female_top_ten_countries = female_population_sorted.head(10)
print("top ten countries female population total \n")
print(female_top_ten_countries[['Country Name', 'Row Total']])
# Out:
# top ten countries female population total
#
#            Country Name     Row Total
# 258               China  1.451207e+10
# 306               India  1.340007e+10
# 423       United States  3.468820e+09
# 307           Indonesia  2.708022e+09
# 243              Brazil  2.213628e+09
# 366            Pakistan  2.127872e+09
# 361             Nigeria  1.847966e+09
# 378  Russian Federation  1.696400e+09
# 232          Bangladesh  1.667168e+09
# 315               Japan  1.435408e+09

# %%
#Bar plot
#Top ten countries of female population
# Create the bar plot
plt.figure(figsize=(15, 6))
plt.subplot(2,2,1)
sns.barplot(x="Row Total", y="Country Name", data=female_top_ten_countries, palette="plasma")
print("top ten countries female population total \n")
plt.title("Top Ten Countries of Female Population",fontsize=10)
plt.xlabel("Total female Population",fontsize=10)
plt.ylabel("Country",fontsize=10)
plt.show()
# Out:
# top ten countries female population total

# %%
#Scatter plot
#Top ten countries of total female population
plt.scatter(x="Row Total", y="Country Name", data=female_top_ten_countries,color='red')
plt.title("Scatter Plot",fontsize=10)
plt.xlabel("Total Female Population",fontsize=10)
plt.ylabel("Country",fontsize=10)
plt.show()
